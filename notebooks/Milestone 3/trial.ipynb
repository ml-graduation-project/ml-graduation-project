# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import  mean_squared_error, r2_score
import joblib
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint,ReduceLROnPlateau
import tensorflow as tf

# %%
index_cols = ["engine", "cycle"]
setting_cols = [f"op_setting_{i}" for i in range(1, 4)]
sensor = [
    "Fan inlet temperature (◦R)",
    "LPC outlet temperature (◦R)",
    "HPC outlet temperature (◦R)",
    "LPT outlet temperature (◦R)",
    "Fan inlet Pressure (psia)",
    "Bypass-duct pressure (psia)",
    "HPC outlet pressure (psia)",
    "Physical fan speed (rpm)",
    "Physical core speed (rpm)",
    "Engine pressure ratio (P50/P2)",
    "HPC outlet Static pressure (psia)",
    "Ratio of fuel flow to Ps30 (pps/psia)",
    "Corrected fan speed (rpm)",
    "Corrected core speed (rpm)",
    "Bypass Ratio",
    "Burner fuel-air ratio",
    "Bleed Enthalpy",
    "Required fan speed",
    "Required fan conversion speed",
    "High-pressure turbines Cool air flow",
    "Low-pressure turbines Cool air flow",
]
col_names = index_cols + setting_cols + sensor
train = pd.read_csv("E:/BoOda/DEPI/Grad Project/ml-graduation-project/data/raw/train_FD001.txt",sep="\s+", header=None, names = col_names) #separate by whitespace, the + is for one or more spaces
test  = pd.read_csv("E:/BoOda/DEPI/Grad Project/ml-graduation-project/data/raw/test_FD001.txt",sep="\s+", header=None, names = col_names)
rul = pd.read_csv("E:/BoOda/DEPI/Grad Project/ml-graduation-project/data/raw/RUL_FD001.txt", sep="\s+", header=None, names=['RUL'])
# Out:
# <>:27: SyntaxWarning: invalid escape sequence '\s'
# <>:28: SyntaxWarning: invalid escape sequence '\s'
# <>:29: SyntaxWarning: invalid escape sequence '\s'
# <>:27: SyntaxWarning: invalid escape sequence '\s'
# <>:28: SyntaxWarning: invalid escape sequence '\s'
# <>:29: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\DiDa\AppData\Local\Temp\ipykernel_18692\3876647335.py:27: SyntaxWarning: invalid escape sequence '\s'
#   train = pd.read_csv("E:/BoOda/DEPI/Grad Project/ml-graduation-project/data/raw/train_FD001.txt",sep="\s+", header=None, names = col_names) #separate by whitespace, the + is for one or more spaces
# C:\Users\DiDa\AppData\Local\Temp\ipykernel_18692\3876647335.py:28: SyntaxWarning: invalid escape sequence '\s'
#   test  = pd.read_csv("E:/BoOda/DEPI/Grad Project/ml-graduation-project/data/raw/test_FD001.txt",sep="\s+", header=None, names = col_names)
# C:\Users\DiDa\AppData\Local\Temp\ipykernel_18692\3876647335.py:29: SyntaxWarning: invalid escape sequence '\s'
#   rul = pd.read_csv("E:/BoOda/DEPI/Grad Project/ml-graduation-project/data/raw/RUL_FD001.txt", sep="\s+", header=None, names=['RUL'])

# %%
if train.columns[-1].startswith('Unnamed'):
    train = train.iloc[:, :-1]
if test.columns[-1].startswith('Unnamed'):
    test = test.iloc[:, :-1]

# %%
train
# Out:
#        engine  cycle  op_setting_1  op_setting_2  op_setting_3  \
# 0           1      1       -0.0007       -0.0004         100.0
# 1           1      2        0.0019       -0.0003         100.0
# 2           1      3       -0.0043        0.0003         100.0
# 3           1      4        0.0007        0.0000         100.0
# 4           1      5       -0.0019       -0.0002         100.0
# ...       ...    ...           ...           ...           ...
# 20626     100    196       -0.0004       -0.0003         100.0
# 20627     100    197       -0.0016       -0.0005         100.0
# 20628     100    198        0.0004        0.0000         100.0
# 20629     100    199       -0.0011        0.0003         100.0
# 20630     100    200       -0.0032       -0.0005         100.0
#
#        Fan inlet temperature (◦R)  LPC outlet temperature (◦R)  \
# 0                          518.67                       641.82
# 1                          518.67                       642.15
# 2                          518.67                       642.35
# 3                          518.67                       642.35
# 4                          518.67                       642.37
# ...                           ...                          ...
# 20626                      518.67                       643.49
# 20627                      518.67                       643.54
# 20628                      518.67                       643.42
# 20629                      518.67                       643.23
# 20630                      518.67                       643.85
#
#        HPC outlet temperature (◦R)  LPT outlet temperature (◦R)  \
# 0                          1589.70                      1400.60
# 1                          1591.82                      1403.14
# 2                          1587.99                      1404.20
# 3                          1582.79                      1401.87
# 4                          1582.85                      1406.22
# ...                            ...                          ...
# 20626                      1597.98                      1428.63
# 20627                      1604.50                      1433.58
# 20628                      1602.46                      1428.18
# 20629                      1605.26                      1426.53
# 20630                      1600.38                      1432.14
#
#        Fan inlet Pressure (psia)  ...  Ratio of fuel flow to Ps30 (pps/psia)  \
# 0                          14.62  ...                                 521.66
# 1                          14.62  ...                                 522.28
# 2                          14.62  ...                                 522.42
# 3                          14.62  ...                                 522.86
# 4                          14.62  ...                                 522.19
# ...                          ...  ...                                    ...
# 20626                      14.62  ...                                 519.49
# 20627                      14.62  ...                                 519.68
# 20628                      14.62  ...                                 520.01
# 20629                      14.62  ...                                 519.67
# 20630                      14.62  ...                                 519.30
#
#        Corrected fan speed (rpm)  Corrected core speed (rpm)  Bypass Ratio  \
# 0                        2388.02                     8138.62        8.4195
# 1                        2388.07                     8131.49        8.4318
# 2                        2388.03                     8133.23        8.4178
# 3                        2388.08                     8133.83        8.3682
# 4                        2388.04                     8133.80        8.4294
# ...                          ...                         ...           ...
# 20626                    2388.26                     8137.60        8.4956
# 20627                    2388.22                     8136.50        8.5139
# 20628                    2388.24                     8141.05        8.5646
# 20629                    2388.23                     8139.29        8.5389
# 20630                    2388.26                     8137.33        8.5036
#
#        Burner fuel-air ratio  Bleed Enthalpy  Required fan speed  \
# 0                       0.03             392                2388
# 1                       0.03             392                2388
# 2                       0.03             390                2388
# 3                       0.03             392                2388
# 4                       0.03             393                2388
# ...                      ...             ...                 ...
# 20626                   0.03             397                2388
# 20627                   0.03             395                2388
# 20628                   0.03             398                2388
# 20629                   0.03             395                2388
# 20630                   0.03             396                2388
#
#        Required fan conversion speed  High-pressure turbines Cool air flow  \
# 0                              100.0                                 39.06
# 1                              100.0                                 39.00
# 2                              100.0                                 38.95
# 3                              100.0                                 38.88
# 4                              100.0                                 38.90
# ...                              ...                                   ...
# 20626                          100.0                                 38.49
# 20627                          100.0                                 38.30
# 20628                          100.0                                 38.44
# 20629                          100.0                                 38.29
# 20630                          100.0                                 38.37
#
#        Low-pressure turbines Cool air flow
# 0                                  23.4190
# 1                                  23.4236
# 2                                  23.3442
# 3                                  23.3739
# 4                                  23.4044
# ...                                    ...
# 20626                              22.9735
# 20627                              23.1594
# 20628                              22.9333
# 20629                              23.0640
# 20630                              23.0522
#
# [20631 rows x 26 columns]

# %%
test
# Out:
#        engine  cycle  op_setting_1  op_setting_2  op_setting_3  \
# 0           1      1        0.0023        0.0003         100.0
# 1           1      2       -0.0027       -0.0003         100.0
# 2           1      3        0.0003        0.0001         100.0
# 3           1      4        0.0042        0.0000         100.0
# 4           1      5        0.0014        0.0000         100.0
# ...       ...    ...           ...           ...           ...
# 13091     100    194        0.0049        0.0000         100.0
# 13092     100    195       -0.0011       -0.0001         100.0
# 13093     100    196       -0.0006       -0.0003         100.0
# 13094     100    197       -0.0038        0.0001         100.0
# 13095     100    198        0.0013        0.0003         100.0
#
#        Fan inlet temperature (◦R)  LPC outlet temperature (◦R)  \
# 0                          518.67                       643.02
# 1                          518.67                       641.71
# 2                          518.67                       642.46
# 3                          518.67                       642.44
# 4                          518.67                       642.51
# ...                           ...                          ...
# 13091                      518.67                       643.24
# 13092                      518.67                       643.22
# 13093                      518.67                       643.44
# 13094                      518.67                       643.26
# 13095                      518.67                       642.95
#
#        HPC outlet temperature (◦R)  LPT outlet temperature (◦R)  \
# 0                          1585.29                      1398.21
# 1                          1588.45                      1395.42
# 2                          1586.94                      1401.34
# 3                          1584.12                      1406.42
# 4                          1587.19                      1401.92
# ...                            ...                          ...
# 13091                      1599.45                      1415.79
# 13092                      1595.69                      1422.05
# 13093                      1593.15                      1406.82
# 13094                      1594.99                      1419.36
# 13095                      1601.62                      1424.99
#
#        Fan inlet Pressure (psia)  ...  Ratio of fuel flow to Ps30 (pps/psia)  \
# 0                          14.62  ...                                 521.72
# 1                          14.62  ...                                 522.16
# 2                          14.62  ...                                 521.97
# 3                          14.62  ...                                 521.38
# 4                          14.62  ...                                 522.15
# ...                          ...  ...                                    ...
# 13091                      14.62  ...                                 520.69
# 13092                      14.62  ...                                 521.05
# 13093                      14.62  ...                                 521.18
# 13094                      14.62  ...                                 521.33
# 13095                      14.62  ...                                 521.07
#
#        Corrected fan speed (rpm)  Corrected core speed (rpm)  Bypass Ratio  \
# 0                        2388.03                     8125.55        8.4052
# 1                        2388.06                     8139.62        8.3803
# 2                        2388.03                     8130.10        8.4441
# 3                        2388.05                     8132.90        8.3917
# 4                        2388.03                     8129.54        8.4031
# ...                          ...                         ...           ...
# 13091                    2388.00                     8213.28        8.4715
# 13092                    2388.09                     8210.85        8.4512
# 13093                    2388.04                     8217.24        8.4569
# 13094                    2388.08                     8220.48        8.4711
# 13095                    2388.05                     8214.64        8.4903
#
#        Burner fuel-air ratio  Bleed Enthalpy  Required fan speed  \
# 0                       0.03             392                2388
# 1                       0.03             393                2388
# 2                       0.03             393                2388
# 3                       0.03             391                2388
# 4                       0.03             390                2388
# ...                      ...             ...                 ...
# 13091                   0.03             394                2388
# 13092                   0.03             395                2388
# 13093                   0.03             395                2388
# 13094                   0.03             395                2388
# 13095                   0.03             396                2388
#
#        Required fan conversion speed  High-pressure turbines Cool air flow  \
# 0                              100.0                                 38.86
# 1                              100.0                                 39.02
# 2                              100.0                                 39.08
# 3                              100.0                                 39.00
# 4                              100.0                                 38.99
# ...                              ...                                   ...
# 13091                          100.0                                 38.65
# 13092                          100.0                                 38.57
# 13093                          100.0                                 38.62
# 13094                          100.0                                 38.66
# 13095                          100.0                                 38.70
#
#        Low-pressure turbines Cool air flow
# 0                                  23.3735
# 1                                  23.3916
# 2                                  23.4166
# 3                                  23.3737
# 4                                  23.4130
# ...                                    ...
# 13091                              23.1974
# 13092                              23.2771
# 13093                              23.2051
# 13094                              23.2699
# 13095                              23.1855
#
# [13096 rows x 26 columns]

# %%
rul.shape
# Out:
# (100, 1)

# %%
train.isna().sum()
# Out:
# engine                                   0
# cycle                                    0
# op_setting_1                             0
# op_setting_2                             0
# op_setting_3                             0
# Fan inlet temperature (◦R)               0
# LPC outlet temperature (◦R)              0
# HPC outlet temperature (◦R)              0
# LPT outlet temperature (◦R)              0
# Fan inlet Pressure (psia)                0
# Bypass-duct pressure (psia)              0
# HPC outlet pressure (psia)               0
# Physical fan speed (rpm)                 0
# Physical core speed (rpm)                0
# Engine pressure ratio (P50/P2)           0
# HPC outlet Static pressure (psia)        0
# Ratio of fuel flow to Ps30 (pps/psia)    0
# Corrected fan speed (rpm)                0
# Corrected core speed (rpm)               0
# Bypass Ratio                             0
# Burner fuel-air ratio                    0
# Bleed Enthalpy                           0
# Required fan speed                       0
# Required fan conversion speed            0
# High-pressure turbines Cool air flow     0
# Low-pressure turbines Cool air flow      0
# dtype: int64

# %%
test.isna().sum()
# Out:
# engine                                   0
# cycle                                    0
# op_setting_1                             0
# op_setting_2                             0
# op_setting_3                             0
# Fan inlet temperature (◦R)               0
# LPC outlet temperature (◦R)              0
# HPC outlet temperature (◦R)              0
# LPT outlet temperature (◦R)              0
# Fan inlet Pressure (psia)                0
# Bypass-duct pressure (psia)              0
# HPC outlet pressure (psia)               0
# Physical fan speed (rpm)                 0
# Physical core speed (rpm)                0
# Engine pressure ratio (P50/P2)           0
# HPC outlet Static pressure (psia)        0
# Ratio of fuel flow to Ps30 (pps/psia)    0
# Corrected fan speed (rpm)                0
# Corrected core speed (rpm)               0
# Bypass Ratio                             0
# Burner fuel-air ratio                    0
# Bleed Enthalpy                           0
# Required fan speed                       0
# Required fan conversion speed            0
# High-pressure turbines Cool air flow     0
# Low-pressure turbines Cool air flow      0
# dtype: int64

# %%
rul.isna().sum()
# Out:
# RUL    0
# dtype: int64

# %%
train.duplicated().sum()
# Out:
# np.int64(0)

# %%
print("Number of engines in train dataset:", train['engine'].nunique())
# Out:
# Number of engines in train dataset: 100

# %%
train.describe().T
# Out:
#                                          count         mean           std  \
# engine                                 20631.0    51.506568  2.922763e+01
# cycle                                  20631.0   108.807862  6.888099e+01
# op_setting_1                           20631.0    -0.000009  2.187313e-03
# op_setting_2                           20631.0     0.000002  2.930621e-04
# op_setting_3                           20631.0   100.000000  0.000000e+00
# Fan inlet temperature (◦R)             20631.0   518.670000  0.000000e+00
# LPC outlet temperature (◦R)            20631.0   642.680934  5.000533e-01
# HPC outlet temperature (◦R)            20631.0  1590.523119  6.131150e+00
# LPT outlet temperature (◦R)            20631.0  1408.933782  9.000605e+00
# Fan inlet Pressure (psia)              20631.0    14.620000  1.776400e-15
# Bypass-duct pressure (psia)            20631.0    21.609803  1.388985e-03
# HPC outlet pressure (psia)             20631.0   553.367711  8.850923e-01
# Physical fan speed (rpm)               20631.0  2388.096652  7.098548e-02
# Physical core speed (rpm)              20631.0  9065.242941  2.208288e+01
# Engine pressure ratio (P50/P2)         20631.0     1.300000  0.000000e+00
# HPC outlet Static pressure (psia)      20631.0    47.541168  2.670874e-01
# Ratio of fuel flow to Ps30 (pps/psia)  20631.0   521.413470  7.375534e-01
# Corrected fan speed (rpm)              20631.0  2388.096152  7.191892e-02
# Corrected core speed (rpm)             20631.0  8143.752722  1.907618e+01
# Bypass Ratio                           20631.0     8.442146  3.750504e-02
# Burner fuel-air ratio                  20631.0     0.030000  1.387812e-17
# Bleed Enthalpy                         20631.0   393.210654  1.548763e+00
# Required fan speed                     20631.0  2388.000000  0.000000e+00
# Required fan conversion speed          20631.0   100.000000  0.000000e+00
# High-pressure turbines Cool air flow   20631.0    38.816271  1.807464e-01
# Low-pressure turbines Cool air flow    20631.0    23.289705  1.082509e-01
#
#                                              min        25%        50%  \
# engine                                    1.0000    26.0000    52.0000
# cycle                                     1.0000    52.0000   104.0000
# op_setting_1                             -0.0087    -0.0015     0.0000
# op_setting_2                             -0.0006    -0.0002     0.0000
# op_setting_3                            100.0000   100.0000   100.0000
# Fan inlet temperature (◦R)              518.6700   518.6700   518.6700
# LPC outlet temperature (◦R)             641.2100   642.3250   642.6400
# HPC outlet temperature (◦R)            1571.0400  1586.2600  1590.1000
# LPT outlet temperature (◦R)            1382.2500  1402.3600  1408.0400
# Fan inlet Pressure (psia)                14.6200    14.6200    14.6200
# Bypass-duct pressure (psia)              21.6000    21.6100    21.6100
# HPC outlet pressure (psia)              549.8500   552.8100   553.4400
# Physical fan speed (rpm)               2387.9000  2388.0500  2388.0900
# Physical core speed (rpm)              9021.7300  9053.1000  9060.6600
# Engine pressure ratio (P50/P2)            1.3000     1.3000     1.3000
# HPC outlet Static pressure (psia)        46.8500    47.3500    47.5100
# Ratio of fuel flow to Ps30 (pps/psia)   518.6900   520.9600   521.4800
# Corrected fan speed (rpm)              2387.8800  2388.0400  2388.0900
# Corrected core speed (rpm)             8099.9400  8133.2450  8140.5400
# Bypass Ratio                              8.3249     8.4149     8.4389
# Burner fuel-air ratio                     0.0300     0.0300     0.0300
# Bleed Enthalpy                          388.0000   392.0000   393.0000
# Required fan speed                     2388.0000  2388.0000  2388.0000
# Required fan conversion speed           100.0000   100.0000   100.0000
# High-pressure turbines Cool air flow     38.1400    38.7000    38.8300
# Low-pressure turbines Cool air flow      22.8942    23.2218    23.2979
#
#                                              75%        max
# engine                                   77.0000   100.0000
# cycle                                   156.0000   362.0000
# op_setting_1                              0.0015     0.0087
# op_setting_2                              0.0003     0.0006
# op_setting_3                            100.0000   100.0000
# Fan inlet temperature (◦R)              518.6700   518.6700
# LPC outlet temperature (◦R)             643.0000   644.5300
# HPC outlet temperature (◦R)            1594.3800  1616.9100
# LPT outlet temperature (◦R)            1414.5550  1441.4900
# Fan inlet Pressure (psia)                14.6200    14.6200
# Bypass-duct pressure (psia)              21.6100    21.6100
# HPC outlet pressure (psia)              554.0100   556.0600
# Physical fan speed (rpm)               2388.1400  2388.5600
# Physical core speed (rpm)              9069.4200  9244.5900
# Engine pressure ratio (P50/P2)            1.3000     1.3000
# HPC outlet Static pressure (psia)        47.7000    48.5300
# Ratio of fuel flow to Ps30 (pps/psia)   521.9500   523.3800
# Corrected fan speed (rpm)              2388.1400  2388.5600
# Corrected core speed (rpm)             8148.3100  8293.7200
# Bypass Ratio                              8.4656     8.5848
# Burner fuel-air ratio                     0.0300     0.0300
# Bleed Enthalpy                          394.0000   400.0000
# Required fan speed                     2388.0000  2388.0000
# Required fan conversion speed           100.0000   100.0000
# High-pressure turbines Cool air flow     38.9500    39.4300
# Low-pressure turbines Cool air flow      23.3668    23.6184

# %%
engine1 = train[train['engine']==1]
plt.figure(figsize=(12, 6))
plt.plot(engine1['cycle'], engine1['LPC outlet temperature (◦R)'], label='LPC Outlet Temperature (s2)', alpha=0.8)
plt.plot(engine1['cycle'], engine1['HPC outlet temperature (◦R)'], label='HPC Outlet Temperature (s3)', alpha=0.8)
plt.plot(engine1['cycle'], engine1['LPT outlet temperature (◦R)'], label='LPT Outlet Temperature (s4)', alpha=0.8)
plt.plot(engine1['cycle'], engine1['Bypass-duct pressure (psia)'], label='Bypass-duct pressure (s6)', alpha=0.8)

plt.xlabel("Cycle (Time)")
plt.ylabel("Sensor Reading (Scaled or Raw)")
plt.title("Engine 1 Degradation: Key Temperature and Pressure Sensors")
plt.legend(loc='upper right')
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %%
#From the description of the dataframe we see some columns who seem to be constant (same min and max values) these wont help us so it is safe to drop them
nunique = train.nunique()
constant_cols = nunique[nunique == 1].index.tolist()
print("Constant sensors:", constant_cols)
# Out:
# Constant sensors: ['op_setting_3', 'Fan inlet temperature (◦R)', 'Fan inlet Pressure (psia)', 'Engine pressure ratio (P50/P2)', 'Burner fuel-air ratio', 'Required fan speed', 'Required fan conversion speed']

# %%
train = train.drop(constant_cols , axis = 1)
test = test.drop(constant_cols , axis = 1)

# %%
train.shape
# Out:
# (20631, 19)

# %%
test.shape
# Out:
# (13096, 19)

# %%
train['max_cycle'] = train.groupby('engine')['cycle'].transform('max')
train['RUL'] = train['max_cycle'] - train['cycle']
train = train.drop('max_cycle', axis=1)
train
# Out:
#        engine  cycle  op_setting_1  op_setting_2  LPC outlet temperature (◦R)  \
# 0           1      1       -0.0007       -0.0004                       641.82
# 1           1      2        0.0019       -0.0003                       642.15
# 2           1      3       -0.0043        0.0003                       642.35
# 3           1      4        0.0007        0.0000                       642.35
# 4           1      5       -0.0019       -0.0002                       642.37
# ...       ...    ...           ...           ...                          ...
# 20626     100    196       -0.0004       -0.0003                       643.49
# 20627     100    197       -0.0016       -0.0005                       643.54
# 20628     100    198        0.0004        0.0000                       643.42
# 20629     100    199       -0.0011        0.0003                       643.23
# 20630     100    200       -0.0032       -0.0005                       643.85
#
#        HPC outlet temperature (◦R)  LPT outlet temperature (◦R)  \
# 0                          1589.70                      1400.60
# 1                          1591.82                      1403.14
# 2                          1587.99                      1404.20
# 3                          1582.79                      1401.87
# 4                          1582.85                      1406.22
# ...                            ...                          ...
# 20626                      1597.98                      1428.63
# 20627                      1604.50                      1433.58
# 20628                      1602.46                      1428.18
# 20629                      1605.26                      1426.53
# 20630                      1600.38                      1432.14
#
#        Bypass-duct pressure (psia)  HPC outlet pressure (psia)  \
# 0                            21.61                      554.36
# 1                            21.61                      553.75
# 2                            21.61                      554.26
# 3                            21.61                      554.45
# 4                            21.61                      554.00
# ...                            ...                         ...
# 20626                        21.61                      551.43
# 20627                        21.61                      550.86
# 20628                        21.61                      550.94
# 20629                        21.61                      550.68
# 20630                        21.61                      550.79
#
#        Physical fan speed (rpm)  Physical core speed (rpm)  \
# 0                       2388.06                    9046.19
# 1                       2388.04                    9044.07
# 2                       2388.08                    9052.94
# 3                       2388.11                    9049.48
# 4                       2388.06                    9055.15
# ...                         ...                        ...
# 20626                   2388.19                    9065.52
# 20627                   2388.23                    9065.11
# 20628                   2388.24                    9065.90
# 20629                   2388.25                    9073.72
# 20630                   2388.26                    9061.48
#
#        HPC outlet Static pressure (psia)  \
# 0                                  47.47
# 1                                  47.49
# 2                                  47.27
# 3                                  47.13
# 4                                  47.28
# ...                                  ...
# 20626                              48.07
# 20627                              48.04
# 20628                              48.09
# 20629                              48.39
# 20630                              48.20
#
#        Ratio of fuel flow to Ps30 (pps/psia)  Corrected fan speed (rpm)  \
# 0                                     521.66                    2388.02
# 1                                     522.28                    2388.07
# 2                                     522.42                    2388.03
# 3                                     522.86                    2388.08
# 4                                     522.19                    2388.04
# ...                                      ...                        ...
# 20626                                 519.49                    2388.26
# 20627                                 519.68                    2388.22
# 20628                                 520.01                    2388.24
# 20629                                 519.67                    2388.23
# 20630                                 519.30                    2388.26
#
#        Corrected core speed (rpm)  Bypass Ratio  Bleed Enthalpy  \
# 0                         8138.62        8.4195             392
# 1                         8131.49        8.4318             392
# 2                         8133.23        8.4178             390
# 3                         8133.83        8.3682             392
# 4                         8133.80        8.4294             393
# ...                           ...           ...             ...
# 20626                     8137.60        8.4956             397
# 20627                     8136.50        8.5139             395
# 20628                     8141.05        8.5646             398
# 20629                     8139.29        8.5389             395
# 20630                     8137.33        8.5036             396
#
#        High-pressure turbines Cool air flow  \
# 0                                     39.06
# 1                                     39.00
# 2                                     38.95
# 3                                     38.88
# 4                                     38.90
# ...                                     ...
# 20626                                 38.49
# 20627                                 38.30
# 20628                                 38.44
# 20629                                 38.29
# 20630                                 38.37
#
#        Low-pressure turbines Cool air flow  RUL
# 0                                  23.4190  191
# 1                                  23.4236  190
# 2                                  23.3442  189
# 3                                  23.3739  188
# 4                                  23.4044  187
# ...                                    ...  ...
# 20626                              22.9735    4
# 20627                              23.1594    3
# 20628                              22.9333    2
# 20629                              23.0640    1
# 20630                              23.0522    0
#
# [20631 rows x 20 columns]

# %%
rul_values= rul['RUL'].values
test['max_cycle'] = test.groupby('engine')['cycle'].transform('max')
test_rul = pd.DataFrame({"engine": test['engine'].unique(), "max_cycle": test.groupby('engine')['cycle'].max().values, "true_RUL": rul_values})

test= test.merge(test_rul, on=['engine', 'max_cycle'], how='left')
test['RUL'] = test['true_RUL'] + (test['max_cycle'] - test['cycle'])
test= test.drop(columns=['max_cycle', 'true_RUL'])
test
# Out:
#        engine  cycle  op_setting_1  op_setting_2  LPC outlet temperature (◦R)  \
# 0           1      1        0.0023        0.0003                       643.02
# 1           1      2       -0.0027       -0.0003                       641.71
# 2           1      3        0.0003        0.0001                       642.46
# 3           1      4        0.0042        0.0000                       642.44
# 4           1      5        0.0014        0.0000                       642.51
# ...       ...    ...           ...           ...                          ...
# 13091     100    194        0.0049        0.0000                       643.24
# 13092     100    195       -0.0011       -0.0001                       643.22
# 13093     100    196       -0.0006       -0.0003                       643.44
# 13094     100    197       -0.0038        0.0001                       643.26
# 13095     100    198        0.0013        0.0003                       642.95
#
#        HPC outlet temperature (◦R)  LPT outlet temperature (◦R)  \
# 0                          1585.29                      1398.21
# 1                          1588.45                      1395.42
# 2                          1586.94                      1401.34
# 3                          1584.12                      1406.42
# 4                          1587.19                      1401.92
# ...                            ...                          ...
# 13091                      1599.45                      1415.79
# 13092                      1595.69                      1422.05
# 13093                      1593.15                      1406.82
# 13094                      1594.99                      1419.36
# 13095                      1601.62                      1424.99
#
#        Bypass-duct pressure (psia)  HPC outlet pressure (psia)  \
# 0                            21.61                      553.90
# 1                            21.61                      554.85
# 2                            21.61                      554.11
# 3                            21.61                      554.07
# 4                            21.61                      554.16
# ...                            ...                         ...
# 13091                        21.61                      553.41
# 13092                        21.61                      553.22
# 13093                        21.61                      553.04
# 13094                        21.61                      553.37
# 13095                        21.61                      552.48
#
#        Physical fan speed (rpm)  Physical core speed (rpm)  \
# 0                       2388.04                    9050.17
# 1                       2388.01                    9054.42
# 2                       2388.05                    9056.96
# 3                       2388.03                    9045.29
# 4                       2388.01                    9044.55
# ...                         ...                        ...
# 13091                   2388.02                    9142.37
# 13092                   2388.05                    9140.68
# 13093                   2388.11                    9146.81
# 13094                   2388.07                    9148.85
# 13095                   2388.06                    9155.03
#
#        HPC outlet Static pressure (psia)  \
# 0                                  47.20
# 1                                  47.50
# 2                                  47.50
# 3                                  47.28
# 4                                  47.31
# ...                                  ...
# 13091                              47.69
# 13092                              47.60
# 13093                              47.57
# 13094                              47.61
# 13095                              47.80
#
#        Ratio of fuel flow to Ps30 (pps/psia)  Corrected fan speed (rpm)  \
# 0                                     521.72                    2388.03
# 1                                     522.16                    2388.06
# 2                                     521.97                    2388.03
# 3                                     521.38                    2388.05
# 4                                     522.15                    2388.03
# ...                                      ...                        ...
# 13091                                 520.69                    2388.00
# 13092                                 521.05                    2388.09
# 13093                                 521.18                    2388.04
# 13094                                 521.33                    2388.08
# 13095                                 521.07                    2388.05
#
#        Corrected core speed (rpm)  Bypass Ratio  Bleed Enthalpy  \
# 0                         8125.55        8.4052             392
# 1                         8139.62        8.3803             393
# 2                         8130.10        8.4441             393
# 3                         8132.90        8.3917             391
# 4                         8129.54        8.4031             390
# ...                           ...           ...             ...
# 13091                     8213.28        8.4715             394
# 13092                     8210.85        8.4512             395
# 13093                     8217.24        8.4569             395
# 13094                     8220.48        8.4711             395
# 13095                     8214.64        8.4903             396
#
#        High-pressure turbines Cool air flow  \
# 0                                     38.86
# 1                                     39.02
# 2                                     39.08
# 3                                     39.00
# 4                                     38.99
# ...                                     ...
# 13091                                 38.65
# 13092                                 38.57
# 13093                                 38.62
# 13094                                 38.66
# 13095                                 38.70
#
#        Low-pressure turbines Cool air flow  RUL
# 0                                  23.3735  142
# 1                                  23.3916  141
# 2                                  23.4166  140
# 3                                  23.3737  139
# 4                                  23.4130  138
# ...                                    ...  ...
# 13091                              23.1974   24
# 13092                              23.2771   23
# 13093                              23.2051   22
# 13094                              23.2699   21
# 13095                              23.1855   20
#
# [13096 rows x 20 columns]

# %%
plt.figure(figsize=(8,5))
sns.histplot(train['RUL'], bins=50, kde=True)
plt.title("Distribution of Remaining Useful Life (RUL)")
plt.xlabel("RUL")
plt.ylabel("Frequency")
plt.show()

# %%
cycles_per_engine = train.groupby('engine')['cycle'].max()
plt.figure(figsize=(8,5))
sns.histplot(cycles_per_engine, bins=30, kde=True)
plt.title("Number of Cycles Before Failure per Engine")
plt.xlabel("Cycles")
plt.ylabel("Count")
plt.show()

# %%
sample_engines = [1, 50, 100]
plt.figure(figsize=(10,6))

for eng in sample_engines:
    subset = train[train['engine'] == eng]
    plt.plot(subset['cycle'], subset['RUL'], label=f'Engine {eng}')

plt.gca().invert_yaxis()
plt.title("RUL Degradation for Sample Engines")
plt.xlabel("Cycle")
plt.ylabel("RUL")
plt.legend()
plt.show()

# %%
sensor_cols = [
    'LPC outlet temperature (◦R)',
    'HPC outlet temperature (◦R)',
    'HPC outlet pressure (psia)',
    'Physical fan speed (rpm)',
    'Physical core speed (rpm)',
    'Bypass Ratio'
]

engine_id = 5
subset = train[train['engine'] == engine_id]

plt.figure(figsize=(12, 10))
for i, col in enumerate(sensor_cols, 1):
    plt.subplot(len(sensor_cols), 1, i)
    plt.plot(subset['cycle'], subset[col], label=col)
    plt.ylabel(col)
    plt.legend()
plt.xlabel("Cycle")
plt.suptitle(f"Sensor Trends for Engine {engine_id}", y=1.02)
plt.tight_layout()
plt.show()

# %%
corr = train.corr(numeric_only=True)
plt.figure(figsize=(10,8))
sns.heatmap(corr[['RUL']].sort_values(by='RUL', ascending=False), annot=True, cmap='coolwarm')
plt.title("Correlation of Sensors with RUL")
plt.show()

# %%
important_sensors = [
    'HPC outlet temperature (◦R)',
    'HPC outlet pressure (psia)',
    'Physical core speed (rpm)',
    'RUL'
]

sns.pairplot(train[important_sensors].sample(1000), diag_kind='kde')
plt.suptitle("Pairwise Relationships Between Key Sensors and RUL", y=1.02)
plt.show()

# %%
pivot_df = train.pivot_table(index='cycle', columns='engine', values='RUL')
plt.figure(figsize=(12,6))
sns.heatmap(pivot_df, cmap='viridis', cbar_kws={'label': 'RUL'})
plt.title("Degradation Progression Across Engines")
plt.xlabel("Engine ID")
plt.ylabel("Cycle")
plt.show()

# %%
feature_var = train.var(numeric_only=True).sort_values(ascending=False)
plt.figure(figsize=(8,5))
sns.barplot(x=feature_var.values[:15], y=feature_var.index[:15])
plt.title("Top 15 Features by Variance")
plt.xlabel("Variance")
plt.ylabel("Feature")
plt.show()

# %%
feature_cols = [c for c in train.columns if c not in ['id', 'cycle', 'RUL']]

X = train[feature_cols].copy()
y = train['RUL'].copy()
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
lr_pred_test = lr.predict(X_test)

# %%
rf = RandomForestRegressor(n_estimators=200, random_state=42)
rf.fit(X_train, y_train)
rf_pred_test = rf.predict(X_test)

# %%
xgb = XGBRegressor(n_estimators=500, learning_rate=0.05, max_depth=5, random_state=42)
xgb.fit(X_train, y_train)
xgb_pred_test = xgb.predict(X_test)

# %%
rmse = np.sqrt(mean_squared_error(y_test, lr_pred_test))
r2 = r2_score(y_test, lr_pred_test)
print(f"Linear Regression → RMSE: {rmse:.2f}, R²: {r2:.3f}")
# Out:
# Linear Regression → RMSE: 44.11, R²: 0.574

# %%
rmse = np.sqrt(mean_squared_error(y_test, rf_pred_test))
r2 = r2_score(y_test, rf_pred_test)
print(f"Random Forest → RMSE: {rmse:.2f}, R²: {r2:.3f}")
# Out:
# Random Forest → RMSE: 30.24, R²: 0.800

# %%
rmse = np.sqrt(mean_squared_error(y_test, xgb_pred_test))
r2 = r2_score(y_test, xgb_pred_test)
print(f"XGB → RMSE: {rmse:.2f}, R²: {r2:.3f}")
# Out:
# XGB → RMSE: 24.83, R²: 0.865

# %% [markdown]
# ## LSTM

# %%
train['RUL'] = train['RUL'].clip(upper=125)

# %%
feature_cols = [c for c in train.columns if c not in ['engine', 'cycle', 'RUL']]
scaler = MinMaxScaler()
train[feature_cols] = scaler.fit_transform(train[feature_cols])
test[feature_cols]  = scaler.transform(test[feature_cols])

# %%
engine_ids = train['engine'].unique()
n_val = int(len(engine_ids) * 0.2)

train_ids = engine_ids[:-n_val]
val_ids   = engine_ids[-n_val:]

train_data = train[train['engine'].isin(train_ids)]
val_data   = train[train['engine'].isin(val_ids)]

# %%
sequence_length = 50

def create_sequences(data, seq_length, features):
    X, y = [], []
    for engine_id in data['engine'].unique():
        engine_data = data[data['engine'] == engine_id]
        vals = engine_data[features].values
        rul_vals = engine_data['RUL'].values
        for i in range(len(vals) - seq_length):
            X.append(vals[i:i+seq_length])
            y.append(rul_vals[i+seq_length])
    return np.array(X), np.array(y)

feature_cols = [c for c in train.columns if c not in ['engine', 'cycle', 'RUL']]
X_train, y_train = create_sequences(train, sequence_length, feature_cols)
X_val, y_val = create_sequences(val_data,sequence_length, feature_cols)
def create_test_last_sequences(df, seq_length, features):
    X, ids = [], []
    for eid in sorted(df['engine'].unique()):
        ed = df[df['engine'] == eid]
        if len(ed) >= seq_length:
            X.append(ed[features].iloc[-seq_length:].values)
            ids.append(eid)
    return np.array(X), ids

X_test, test_ids = create_test_last_sequences(test, sequence_length, feature_cols)
rul_df = rul.reset_index()
rul_df['engine'] = rul_df.index + 1 
y_test = rul_df.set_index('engine').loc[test_ids]['RUL'].values

# %%
model = Sequential([
    LSTM(128, activation='tanh', return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])),
    Dropout(0.2),
    LSTM(64, activation='tanh'),
    Dense(32, activation='relu'),
    Dense(1)
])

optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss="mse", metrics=[tf.keras.metrics.RootMeanSquaredError()])
lr_reducer = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1)

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
checkpoint = ModelCheckpoint('best_lstm_fd001.keras', monitor='val_loss', save_best_only=True)
lr_reduce  = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1)
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=150,
    batch_size=64,
    shuffle=False,           # very important for time-series
    callbacks=[early_stop, lr_reduce],
    verbose=1
)
# Out:
# Epoch 1/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - loss: 3462.8748 - root_mean_squared_error: 58.8462 - val_loss: 1837.2423 - val_root_mean_squared_error: 42.8631 - learning_rate: 0.0010
# Epoch 2/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 11s 45ms/step - loss: 1713.9467 - root_mean_squared_error: 41.3998 - val_loss: 1772.7698 - val_root_mean_squared_error: 42.1043 - learning_rate: 0.0010
# Epoch 3/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 11s 46ms/step - loss: 1713.4474 - root_mean_squared_error: 41.3938 - val_loss: 1772.5085 - val_root_mean_squared_error: 42.1012 - learning_rate: 0.0010
# Epoch 4/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 11s 47ms/step - loss: 1713.4574 - root_mean_squared_error: 41.3939 - val_loss: 1772.4636 - val_root_mean_squared_error: 42.1006 - learning_rate: 0.0010
# Epoch 5/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 11s 46ms/step - loss: 1713.4546 - root_mean_squared_error: 41.3939 - val_loss: 1772.4354 - val_root_mean_squared_error: 42.1003 - learning_rate: 0.0010
# Epoch 6/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 11s 46ms/step - loss: 1713.4365 - root_mean_squared_error: 41.3937 - val_loss: 1772.4165 - val_root_mean_squared_error: 42.1001 - learning_rate: 0.0010
# Epoch 7/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 11s 46ms/step - loss: 1713.4476 - root_mean_squared_error: 41.3938 - val_loss: 1772.4022 - val_root_mean_squared_error: 42.0999 - learning_rate: 0.0010
# Epoch 8/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - loss: 1713.4371 - root_mean_squared_error: 41.3937 - val_loss: 1772.3876 - val_root_mean_squared_error: 42.0997 - learning_rate: 0.0010
# Epoch 9/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 11s 47ms/step - loss: 1713.4368 - root_mean_squared_error: 41.3937 - val_loss: 1772.3822 - val_root_mean_squared_error: 42.0997 - learning_rate: 0.0010
# Epoch 10/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 11s 47ms/step - loss: 1713.4160 - root_mean_squared_error: 41.3934 - val_loss: 1772.3527 - val_root_mean_squared_error: 42.0993 - learning_rate: 0.0010
# Epoch 11/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 11s 46ms/step - loss: 1713.2507 - root_mean_squared_error: 41.3914 - val_loss: 1771.8032 - val_root_mean_squared_error: 42.0928 - learning_rate: 0.0010
# Epoch 12/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 51ms/step - loss: 2834.2581 - root_mean_squared_error: 53.2378 - val_loss: 1758.7828 - val_root_mean_squared_error: 41.9378 - learning_rate: 0.0010
# Epoch 13/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - loss: 939.2864 - root_mean_squared_error: 30.6478 - val_loss: 585.0165 - val_root_mean_squared_error: 24.1871 - learning_rate: 0.0010
# Epoch 14/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - loss: 531.2241 - root_mean_squared_error: 23.0483 - val_loss: 373.6396 - val_root_mean_squared_error: 19.3298 - learning_rate: 0.0010
# Epoch 15/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 464.1061 - root_mean_squared_error: 21.5431 - val_loss: 417.2772 - val_root_mean_squared_error: 20.4274 - learning_rate: 0.0010
# Epoch 16/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 20s 48ms/step - loss: 393.6136 - root_mean_squared_error: 19.8397 - val_loss: 331.8902 - val_root_mean_squared_error: 18.2179 - learning_rate: 0.0010
# Epoch 17/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 341.9188 - root_mean_squared_error: 18.4910 - val_loss: 264.7549 - val_root_mean_squared_error: 16.2713 - learning_rate: 0.0010
# Epoch 18/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - loss: 292.7094 - root_mean_squared_error: 17.1088 - val_loss: 218.6970 - val_root_mean_squared_error: 14.7884 - learning_rate: 0.0010
# Epoch 19/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - loss: 269.0564 - root_mean_squared_error: 16.4029 - val_loss: 183.7794 - val_root_mean_squared_error: 13.5565 - learning_rate: 0.0010
# Epoch 20/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - loss: 263.3238 - root_mean_squared_error: 16.2273 - val_loss: 203.4714 - val_root_mean_squared_error: 14.2643 - learning_rate: 0.0010
# Epoch 21/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - loss: 245.3670 - root_mean_squared_error: 15.6642 - val_loss: 168.5808 - val_root_mean_squared_error: 12.9839 - learning_rate: 0.0010
# Epoch 22/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - loss: 231.8351 - root_mean_squared_error: 15.2261 - val_loss: 163.3969 - val_root_mean_squared_error: 12.7827 - learning_rate: 0.0010
# Epoch 23/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - loss: 217.9509 - root_mean_squared_error: 14.7632 - val_loss: 158.1690 - val_root_mean_squared_error: 12.5765 - learning_rate: 0.0010
# Epoch 24/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - loss: 211.2045 - root_mean_squared_error: 14.5329 - val_loss: 152.3668 - val_root_mean_squared_error: 12.3437 - learning_rate: 0.0010
# Epoch 25/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 208.0710 - root_mean_squared_error: 14.4247 - val_loss: 153.0084 - val_root_mean_squared_error: 12.3697 - learning_rate: 0.0010
# Epoch 26/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - loss: 205.4936 - root_mean_squared_error: 14.3350 - val_loss: 140.5496 - val_root_mean_squared_error: 11.8554 - learning_rate: 0.0010
# Epoch 27/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 205.8058 - root_mean_squared_error: 14.3459 - val_loss: 138.0027 - val_root_mean_squared_error: 11.7475 - learning_rate: 0.0010
# Epoch 28/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 204.3214 - root_mean_squared_error: 14.2941 - val_loss: 132.8550 - val_root_mean_squared_error: 11.5263 - learning_rate: 0.0010
# Epoch 29/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 202.9475 - root_mean_squared_error: 14.2460 - val_loss: 133.6073 - val_root_mean_squared_error: 11.5589 - learning_rate: 0.0010
# Epoch 30/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - loss: 197.0049 - root_mean_squared_error: 14.0358 - val_loss: 128.8022 - val_root_mean_squared_error: 11.3491 - learning_rate: 0.0010
# Epoch 31/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 198.0165 - root_mean_squared_error: 14.0718 - val_loss: 127.8259 - val_root_mean_squared_error: 11.3060 - learning_rate: 0.0010
# Epoch 32/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - loss: 192.5978 - root_mean_squared_error: 13.8780 - val_loss: 127.6180 - val_root_mean_squared_error: 11.2968 - learning_rate: 0.0010
# Epoch 33/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 191.9433 - root_mean_squared_error: 13.8544 - val_loss: 126.2487 - val_root_mean_squared_error: 11.2360 - learning_rate: 0.0010
# Epoch 34/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - loss: 186.5171 - root_mean_squared_error: 13.6571 - val_loss: 125.9967 - val_root_mean_squared_error: 11.2248 - learning_rate: 0.0010
# Epoch 35/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - loss: 188.6704 - root_mean_squared_error: 13.7357 - val_loss: 125.4296 - val_root_mean_squared_error: 11.1995 - learning_rate: 0.0010
# Epoch 36/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - loss: 180.8850 - root_mean_squared_error: 13.4493 - val_loss: 124.4920 - val_root_mean_squared_error: 11.1576 - learning_rate: 0.0010
# Epoch 37/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 177.0449 - root_mean_squared_error: 13.3058 - val_loss: 124.0498 - val_root_mean_squared_error: 11.1378 - learning_rate: 0.0010
# Epoch 38/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - loss: 177.8429 - root_mean_squared_error: 13.3358 - val_loss: 123.3478 - val_root_mean_squared_error: 11.1062 - learning_rate: 0.0010
# Epoch 39/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - loss: 176.2370 - root_mean_squared_error: 13.2754 - val_loss: 125.3814 - val_root_mean_squared_error: 11.1974 - learning_rate: 0.0010
# Epoch 40/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - loss: 175.4744 - root_mean_squared_error: 13.2467 - val_loss: 123.4150 - val_root_mean_squared_error: 11.1092 - learning_rate: 0.0010
# Epoch 41/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - loss: 174.3765 - root_mean_squared_error: 13.2052 - val_loss: 124.6348 - val_root_mean_squared_error: 11.1640 - learning_rate: 0.0010
# Epoch 42/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - loss: 171.5487 - root_mean_squared_error: 13.0977 - val_loss: 125.1602 - val_root_mean_squared_error: 11.1875 - learning_rate: 0.0010
# Epoch 43/150
# 244/245 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 159.5666 - root_mean_squared_error: 12.5965
# Epoch 43: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 173.9326 - root_mean_squared_error: 13.1884 - val_loss: 125.9807 - val_root_mean_squared_error: 11.2241 - learning_rate: 0.0010
# Epoch 44/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - loss: 156.4532 - root_mean_squared_error: 12.5081 - val_loss: 117.0388 - val_root_mean_squared_error: 10.8184 - learning_rate: 5.0000e-04
# Epoch 45/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 154.8687 - root_mean_squared_error: 12.4446 - val_loss: 116.0489 - val_root_mean_squared_error: 10.7726 - learning_rate: 5.0000e-04
# Epoch 46/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - loss: 153.7798 - root_mean_squared_error: 12.4008 - val_loss: 115.7771 - val_root_mean_squared_error: 10.7600 - learning_rate: 5.0000e-04
# Epoch 47/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 153.9837 - root_mean_squared_error: 12.4090 - val_loss: 115.9681 - val_root_mean_squared_error: 10.7688 - learning_rate: 5.0000e-04
# Epoch 48/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 153.5872 - root_mean_squared_error: 12.3930 - val_loss: 114.5766 - val_root_mean_squared_error: 10.7040 - learning_rate: 5.0000e-04
# Epoch 49/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 152.3350 - root_mean_squared_error: 12.3424 - val_loss: 115.0649 - val_root_mean_squared_error: 10.7268 - learning_rate: 5.0000e-04
# Epoch 50/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 152.1175 - root_mean_squared_error: 12.3336 - val_loss: 114.1715 - val_root_mean_squared_error: 10.6851 - learning_rate: 5.0000e-04
# Epoch 51/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 150.6905 - root_mean_squared_error: 12.2756 - val_loss: 114.1199 - val_root_mean_squared_error: 10.6827 - learning_rate: 5.0000e-04
# Epoch 52/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 151.0965 - root_mean_squared_error: 12.2921 - val_loss: 115.0164 - val_root_mean_squared_error: 10.7246 - learning_rate: 5.0000e-04
# Epoch 53/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 151.0244 - root_mean_squared_error: 12.2892 - val_loss: 114.3698 - val_root_mean_squared_error: 10.6944 - learning_rate: 5.0000e-04
# Epoch 54/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 151.0638 - root_mean_squared_error: 12.2908 - val_loss: 114.9842 - val_root_mean_squared_error: 10.7231 - learning_rate: 5.0000e-04
# Epoch 55/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 150.1563 - root_mean_squared_error: 12.2538 - val_loss: 115.3572 - val_root_mean_squared_error: 10.7404 - learning_rate: 5.0000e-04
# Epoch 56/150
# 244/245 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 143.7449 - root_mean_squared_error: 11.9681
# Epoch 56: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - loss: 149.9394 - root_mean_squared_error: 12.2450 - val_loss: 114.5101 - val_root_mean_squared_error: 10.7009 - learning_rate: 5.0000e-04
# Epoch 57/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 142.9762 - root_mean_squared_error: 11.9573 - val_loss: 111.8454 - val_root_mean_squared_error: 10.5757 - learning_rate: 2.5000e-04
# Epoch 58/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 140.8981 - root_mean_squared_error: 11.8701 - val_loss: 111.1744 - val_root_mean_squared_error: 10.5439 - learning_rate: 2.5000e-04
# Epoch 59/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 141.2345 - root_mean_squared_error: 11.8842 - val_loss: 110.6723 - val_root_mean_squared_error: 10.5201 - learning_rate: 2.5000e-04
# Epoch 60/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 51ms/step - loss: 139.8830 - root_mean_squared_error: 11.8272 - val_loss: 110.2267 - val_root_mean_squared_error: 10.4989 - learning_rate: 2.5000e-04
# Epoch 61/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - loss: 139.1317 - root_mean_squared_error: 11.7954 - val_loss: 109.9240 - val_root_mean_squared_error: 10.4845 - learning_rate: 2.5000e-04
# Epoch 62/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - loss: 139.6562 - root_mean_squared_error: 11.8176 - val_loss: 109.7497 - val_root_mean_squared_error: 10.4762 - learning_rate: 2.5000e-04
# Epoch 63/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - loss: 139.6191 - root_mean_squared_error: 11.8161 - val_loss: 109.7848 - val_root_mean_squared_error: 10.4778 - learning_rate: 2.5000e-04
# Epoch 64/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - loss: 138.8638 - root_mean_squared_error: 11.7840 - val_loss: 109.4886 - val_root_mean_squared_error: 10.4637 - learning_rate: 2.5000e-04
# Epoch 65/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - loss: 138.0897 - root_mean_squared_error: 11.7512 - val_loss: 109.3651 - val_root_mean_squared_error: 10.4578 - learning_rate: 2.5000e-04
# Epoch 66/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - loss: 137.8351 - root_mean_squared_error: 11.7403 - val_loss: 109.0403 - val_root_mean_squared_error: 10.4422 - learning_rate: 2.5000e-04
# Epoch 67/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - loss: 137.7253 - root_mean_squared_error: 11.7356 - val_loss: 108.8667 - val_root_mean_squared_error: 10.4339 - learning_rate: 2.5000e-04
# Epoch 68/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - loss: 137.6963 - root_mean_squared_error: 11.7344 - val_loss: 108.6152 - val_root_mean_squared_error: 10.4219 - learning_rate: 2.5000e-04
# Epoch 69/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - loss: 137.1672 - root_mean_squared_error: 11.7118 - val_loss: 108.6734 - val_root_mean_squared_error: 10.4247 - learning_rate: 2.5000e-04
# Epoch 70/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - loss: 136.6165 - root_mean_squared_error: 11.6883 - val_loss: 108.4203 - val_root_mean_squared_error: 10.4125 - learning_rate: 2.5000e-04
# Epoch 71/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 135.9216 - root_mean_squared_error: 11.6585 - val_loss: 108.2090 - val_root_mean_squared_error: 10.4024 - learning_rate: 2.5000e-04
# Epoch 72/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - loss: 137.0031 - root_mean_squared_error: 11.7048 - val_loss: 108.2001 - val_root_mean_squared_error: 10.4019 - learning_rate: 2.5000e-04
# Epoch 73/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 135.7428 - root_mean_squared_error: 11.6509 - val_loss: 108.0851 - val_root_mean_squared_error: 10.3964 - learning_rate: 2.5000e-04
# Epoch 74/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 135.9741 - root_mean_squared_error: 11.6608 - val_loss: 107.8253 - val_root_mean_squared_error: 10.3839 - learning_rate: 2.5000e-04
# Epoch 75/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - loss: 135.3212 - root_mean_squared_error: 11.6328 - val_loss: 108.0140 - val_root_mean_squared_error: 10.3930 - learning_rate: 2.5000e-04
# Epoch 76/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - loss: 135.5649 - root_mean_squared_error: 11.6432 - val_loss: 107.8680 - val_root_mean_squared_error: 10.3860 - learning_rate: 2.5000e-04
# Epoch 77/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 135.7379 - root_mean_squared_error: 11.6507 - val_loss: 107.4738 - val_root_mean_squared_error: 10.3670 - learning_rate: 2.5000e-04
# Epoch 78/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - loss: 134.6485 - root_mean_squared_error: 11.6038 - val_loss: 107.3254 - val_root_mean_squared_error: 10.3598 - learning_rate: 2.5000e-04
# Epoch 79/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 133.8540 - root_mean_squared_error: 11.5695 - val_loss: 107.1756 - val_root_mean_squared_error: 10.3526 - learning_rate: 2.5000e-04
# Epoch 80/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - loss: 133.3955 - root_mean_squared_error: 11.5497 - val_loss: 107.3150 - val_root_mean_squared_error: 10.3593 - learning_rate: 2.5000e-04
# Epoch 81/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 133.4213 - root_mean_squared_error: 11.5508 - val_loss: 107.4583 - val_root_mean_squared_error: 10.3662 - learning_rate: 2.5000e-04
# Epoch 82/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 133.5686 - root_mean_squared_error: 11.5572 - val_loss: 107.2696 - val_root_mean_squared_error: 10.3571 - learning_rate: 2.5000e-04
# Epoch 83/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 132.7519 - root_mean_squared_error: 11.5218 - val_loss: 107.5941 - val_root_mean_squared_error: 10.3728 - learning_rate: 2.5000e-04
# Epoch 84/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 125.8264 - root_mean_squared_error: 11.1982
# Epoch 84: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 132.2055 - root_mean_squared_error: 11.4981 - val_loss: 107.2036 - val_root_mean_squared_error: 10.3539 - learning_rate: 2.5000e-04
# Epoch 85/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 130.4817 - root_mean_squared_error: 11.4229 - val_loss: 107.2131 - val_root_mean_squared_error: 10.3544 - learning_rate: 1.2500e-04
# Epoch 86/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - loss: 128.4905 - root_mean_squared_error: 11.3354 - val_loss: 107.4127 - val_root_mean_squared_error: 10.3640 - learning_rate: 1.2500e-04
# Epoch 87/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 128.1261 - root_mean_squared_error: 11.3193 - val_loss: 107.1523 - val_root_mean_squared_error: 10.3514 - learning_rate: 1.2500e-04
# Epoch 88/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 127.8113 - root_mean_squared_error: 11.3054 - val_loss: 107.0621 - val_root_mean_squared_error: 10.3471 - learning_rate: 1.2500e-04
# Epoch 89/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 127.2353 - root_mean_squared_error: 11.2799 - val_loss: 106.9303 - val_root_mean_squared_error: 10.3407 - learning_rate: 1.2500e-04
# Epoch 90/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - loss: 127.8554 - root_mean_squared_error: 11.3073 - val_loss: 107.1100 - val_root_mean_squared_error: 10.3494 - learning_rate: 1.2500e-04
# Epoch 91/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 127.1355 - root_mean_squared_error: 11.2754 - val_loss: 106.7897 - val_root_mean_squared_error: 10.3339 - learning_rate: 1.2500e-04
# Epoch 92/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - loss: 127.2299 - root_mean_squared_error: 11.2796 - val_loss: 106.7680 - val_root_mean_squared_error: 10.3329 - learning_rate: 1.2500e-04
# Epoch 93/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 126.8727 - root_mean_squared_error: 11.2638 - val_loss: 106.5663 - val_root_mean_squared_error: 10.3231 - learning_rate: 1.2500e-04
# Epoch 94/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 126.9724 - root_mean_squared_error: 11.2682 - val_loss: 106.3670 - val_root_mean_squared_error: 10.3134 - learning_rate: 1.2500e-04
# Epoch 95/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 126.5980 - root_mean_squared_error: 11.2516 - val_loss: 106.2700 - val_root_mean_squared_error: 10.3087 - learning_rate: 1.2500e-04
# Epoch 96/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - loss: 126.5664 - root_mean_squared_error: 11.2502 - val_loss: 106.3233 - val_root_mean_squared_error: 10.3113 - learning_rate: 1.2500e-04
# Epoch 97/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 50ms/step - loss: 125.8340 - root_mean_squared_error: 11.2176 - val_loss: 105.7676 - val_root_mean_squared_error: 10.2843 - learning_rate: 1.2500e-04
# Epoch 98/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - loss: 126.2839 - root_mean_squared_error: 11.2376 - val_loss: 106.1130 - val_root_mean_squared_error: 10.3011 - learning_rate: 1.2500e-04
# Epoch 99/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 50ms/step - loss: 126.2154 - root_mean_squared_error: 11.2346 - val_loss: 105.9109 - val_root_mean_squared_error: 10.2913 - learning_rate: 1.2500e-04
# Epoch 100/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 125.8565 - root_mean_squared_error: 11.2186 - val_loss: 105.9193 - val_root_mean_squared_error: 10.2917 - learning_rate: 1.2500e-04
# Epoch 101/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - loss: 124.6727 - root_mean_squared_error: 11.1657 - val_loss: 105.7591 - val_root_mean_squared_error: 10.2839 - learning_rate: 1.2500e-04
# Epoch 102/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 50ms/step - loss: 125.2794 - root_mean_squared_error: 11.1928 - val_loss: 105.3714 - val_root_mean_squared_error: 10.2651 - learning_rate: 1.2500e-04
# Epoch 103/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 50ms/step - loss: 125.3601 - root_mean_squared_error: 11.1964 - val_loss: 105.3988 - val_root_mean_squared_error: 10.2664 - learning_rate: 1.2500e-04
# Epoch 104/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 13s 54ms/step - loss: 125.3061 - root_mean_squared_error: 11.1940 - val_loss: 105.4490 - val_root_mean_squared_error: 10.2688 - learning_rate: 1.2500e-04
# Epoch 105/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 13s 53ms/step - loss: 124.4960 - root_mean_squared_error: 11.1578 - val_loss: 105.1309 - val_root_mean_squared_error: 10.2533 - learning_rate: 1.2500e-04
# Epoch 106/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 13s 52ms/step - loss: 124.9172 - root_mean_squared_error: 11.1766 - val_loss: 104.9777 - val_root_mean_squared_error: 10.2459 - learning_rate: 1.2500e-04
# Epoch 107/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - loss: 123.9364 - root_mean_squared_error: 11.1327 - val_loss: 105.1362 - val_root_mean_squared_error: 10.2536 - learning_rate: 1.2500e-04
# Epoch 108/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - loss: 124.6110 - root_mean_squared_error: 11.1629 - val_loss: 104.7945 - val_root_mean_squared_error: 10.2369 - learning_rate: 1.2500e-04
# Epoch 109/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 50ms/step - loss: 124.3218 - root_mean_squared_error: 11.1500 - val_loss: 105.0101 - val_root_mean_squared_error: 10.2474 - learning_rate: 1.2500e-04
# Epoch 110/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - loss: 124.1171 - root_mean_squared_error: 11.1408 - val_loss: 104.4440 - val_root_mean_squared_error: 10.2198 - learning_rate: 1.2500e-04
# Epoch 111/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 50ms/step - loss: 124.3481 - root_mean_squared_error: 11.1511 - val_loss: 104.7244 - val_root_mean_squared_error: 10.2335 - learning_rate: 1.2500e-04
# Epoch 112/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 124.7184 - root_mean_squared_error: 11.1677 - val_loss: 104.4565 - val_root_mean_squared_error: 10.2204 - learning_rate: 1.2500e-04
# Epoch 113/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - loss: 124.5382 - root_mean_squared_error: 11.1597 - val_loss: 104.5377 - val_root_mean_squared_error: 10.2244 - learning_rate: 1.2500e-04
# Epoch 114/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - loss: 124.4828 - root_mean_squared_error: 11.1572 - val_loss: 104.3916 - val_root_mean_squared_error: 10.2172 - learning_rate: 1.2500e-04
# Epoch 115/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - loss: 124.1277 - root_mean_squared_error: 11.1413 - val_loss: 104.4146 - val_root_mean_squared_error: 10.2183 - learning_rate: 1.2500e-04
# Epoch 116/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - loss: 123.5006 - root_mean_squared_error: 11.1131 - val_loss: 104.1553 - val_root_mean_squared_error: 10.2057 - learning_rate: 1.2500e-04
# Epoch 117/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 123.7389 - root_mean_squared_error: 11.1238 - val_loss: 103.9878 - val_root_mean_squared_error: 10.1974 - learning_rate: 1.2500e-04
# Epoch 118/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 50ms/step - loss: 123.4891 - root_mean_squared_error: 11.1126 - val_loss: 104.0390 - val_root_mean_squared_error: 10.1999 - learning_rate: 1.2500e-04
# Epoch 119/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 122.9088 - root_mean_squared_error: 11.0864 - val_loss: 104.0268 - val_root_mean_squared_error: 10.1994 - learning_rate: 1.2500e-04
# Epoch 120/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - loss: 123.7294 - root_mean_squared_error: 11.1234 - val_loss: 103.9339 - val_root_mean_squared_error: 10.1948 - learning_rate: 1.2500e-04
# Epoch 121/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - loss: 122.9528 - root_mean_squared_error: 11.0884 - val_loss: 103.6230 - val_root_mean_squared_error: 10.1795 - learning_rate: 1.2500e-04
# Epoch 122/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - loss: 122.9341 - root_mean_squared_error: 11.0876 - val_loss: 103.5480 - val_root_mean_squared_error: 10.1759 - learning_rate: 1.2500e-04
# Epoch 123/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - loss: 122.2553 - root_mean_squared_error: 11.0569 - val_loss: 103.1342 - val_root_mean_squared_error: 10.1555 - learning_rate: 1.2500e-04
# Epoch 124/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 122.6280 - root_mean_squared_error: 11.0738 - val_loss: 103.1049 - val_root_mean_squared_error: 10.1541 - learning_rate: 1.2500e-04
# Epoch 125/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - loss: 122.4891 - root_mean_squared_error: 11.0675 - val_loss: 103.1313 - val_root_mean_squared_error: 10.1554 - learning_rate: 1.2500e-04
# Epoch 126/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - loss: 121.5098 - root_mean_squared_error: 11.0231 - val_loss: 103.2440 - val_root_mean_squared_error: 10.1609 - learning_rate: 1.2500e-04
# Epoch 127/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 121.8244 - root_mean_squared_error: 11.0374 - val_loss: 103.0836 - val_root_mean_squared_error: 10.1530 - learning_rate: 1.2500e-04
# Epoch 128/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - loss: 122.3118 - root_mean_squared_error: 11.0595 - val_loss: 102.9480 - val_root_mean_squared_error: 10.1463 - learning_rate: 1.2500e-04
# Epoch 129/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - loss: 122.1789 - root_mean_squared_error: 11.0535 - val_loss: 102.6889 - val_root_mean_squared_error: 10.1336 - learning_rate: 1.2500e-04
# Epoch 130/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - loss: 122.5202 - root_mean_squared_error: 11.0689 - val_loss: 102.6546 - val_root_mean_squared_error: 10.1319 - learning_rate: 1.2500e-04
# Epoch 131/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 121.1574 - root_mean_squared_error: 11.0072 - val_loss: 102.4681 - val_root_mean_squared_error: 10.1227 - learning_rate: 1.2500e-04
# Epoch 132/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - loss: 121.6684 - root_mean_squared_error: 11.0303 - val_loss: 102.4169 - val_root_mean_squared_error: 10.1201 - learning_rate: 1.2500e-04
# Epoch 133/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 51ms/step - loss: 121.3448 - root_mean_squared_error: 11.0157 - val_loss: 102.2261 - val_root_mean_squared_error: 10.1107 - learning_rate: 1.2500e-04
# Epoch 134/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 50ms/step - loss: 121.1929 - root_mean_squared_error: 11.0088 - val_loss: 102.1280 - val_root_mean_squared_error: 10.1058 - learning_rate: 1.2500e-04
# Epoch 135/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 121.5452 - root_mean_squared_error: 11.0248 - val_loss: 102.0276 - val_root_mean_squared_error: 10.1009 - learning_rate: 1.2500e-04
# Epoch 136/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 121.2872 - root_mean_squared_error: 11.0130 - val_loss: 101.7559 - val_root_mean_squared_error: 10.0874 - learning_rate: 1.2500e-04
# Epoch 137/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 120.6930 - root_mean_squared_error: 10.9860 - val_loss: 101.7035 - val_root_mean_squared_error: 10.0848 - learning_rate: 1.2500e-04
# Epoch 138/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 120.6811 - root_mean_squared_error: 10.9855 - val_loss: 101.5448 - val_root_mean_squared_error: 10.0769 - learning_rate: 1.2500e-04
# Epoch 139/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - loss: 121.3902 - root_mean_squared_error: 11.0177 - val_loss: 101.3425 - val_root_mean_squared_error: 10.0669 - learning_rate: 1.2500e-04
# Epoch 140/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 121.0464 - root_mean_squared_error: 11.0021 - val_loss: 101.2789 - val_root_mean_squared_error: 10.0637 - learning_rate: 1.2500e-04
# Epoch 141/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 120.8099 - root_mean_squared_error: 10.9914 - val_loss: 101.3677 - val_root_mean_squared_error: 10.0682 - learning_rate: 1.2500e-04
# Epoch 142/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 120.4283 - root_mean_squared_error: 10.9740 - val_loss: 101.3141 - val_root_mean_squared_error: 10.0655 - learning_rate: 1.2500e-04
# Epoch 143/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 120.6885 - root_mean_squared_error: 10.9858 - val_loss: 100.9329 - val_root_mean_squared_error: 10.0465 - learning_rate: 1.2500e-04
# Epoch 144/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 120.4208 - root_mean_squared_error: 10.9736 - val_loss: 101.1847 - val_root_mean_squared_error: 10.0591 - learning_rate: 1.2500e-04
# Epoch 145/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 119.9774 - root_mean_squared_error: 10.9534 - val_loss: 100.9809 - val_root_mean_squared_error: 10.0489 - learning_rate: 1.2500e-04
# Epoch 146/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - loss: 120.1125 - root_mean_squared_error: 10.9596 - val_loss: 100.7490 - val_root_mean_squared_error: 10.0374 - learning_rate: 1.2500e-04
# Epoch 147/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 119.4601 - root_mean_squared_error: 10.9298 - val_loss: 100.5087 - val_root_mean_squared_error: 10.0254 - learning_rate: 1.2500e-04
# Epoch 148/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - loss: 120.1269 - root_mean_squared_error: 10.9602 - val_loss: 100.4438 - val_root_mean_squared_error: 10.0222 - learning_rate: 1.2500e-04
# Epoch 149/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - loss: 120.2417 - root_mean_squared_error: 10.9655 - val_loss: 100.4648 - val_root_mean_squared_error: 10.0232 - learning_rate: 1.2500e-04
# Epoch 150/150
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 12s 49ms/step - loss: 119.3872 - root_mean_squared_error: 10.9264 - val_loss: 100.3544 - val_root_mean_squared_error: 10.0177 - learning_rate: 1.2500e-04

# %%
#model = load_model('best_lstm_fd001.keras')

# %%
y_train_pred = model.predict(X_train)
train_rmse = np.sqrt(mean_squared_error(y_train, y_train_pred))
train_r2 = r2_score(y_train, y_train_pred)
print(f"LSTM Train Results → RMSE: {train_rmse:.2f}, R²: {train_r2:.3f}")
# Out:
# 489/489 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step
# LSTM Train Results → RMSE: 11.08, R²: 0.928

# %%
y_pred = model.predict(X_test)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

print(f"LSTM Test Results → RMSE: {rmse:.2f}, R²: {r2:.3f}")
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# LSTM Test Results → RMSE: 14.35, R²: 0.878

# %%
plt.figure(figsize=(10,5))
plt.plot(y_test, label='Actual RUL', color='blue', linewidth=2)
plt.plot(y_pred, label='Predicted RUL', color='red', linestyle='--', linewidth=2)
plt.title('Predicted vs Actual Remaining Useful Life (RUL)')
plt.xlabel('Sample')
plt.ylabel('RUL')
plt.legend()
plt.grid(True)
plt.show()

# %%
engine_id = 50
engine_data = test[test['engine'] == engine_id]
X_engine, y_engine = create_sequences(engine_data, sequence_length, feature_cols)
y_pred_engine = model.predict(X_engine)
smooth_window = 10
smooth_pred = np.convolve(y_pred_engine.flatten(), np.ones(smooth_window)/smooth_window, mode='valid')


plt.figure(figsize=(8, 5))
plt.plot(y_engine[:len(smooth_pred)], label='Actual RUL', color='blue')
plt.plot(smooth_pred, label='Smoothed Predicted RUL', color='red', linestyle='--')
plt.title(f'Engine {engine_id} - RUL over cycles')
plt.xlabel('Cycle')
plt.ylabel('RUL')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
